# %% [markdown]
# ## matplotlib

# %%
import matplotlib.pyplot as plt

# data values for the x and y axis
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# create a line chart, years on x-axis, gdp on y-axis
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

# title and labels for the x and y axis
plt.title("Nominal GDP")
plt.xlabel("Year")
plt.ylabel("Billions of $")

# show the graph
plt.show()

# %% [markdown]
# ## Bar Charts

# %%
import matplotlib.pyplot as plt

# data values for the x and y axis
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

# fix bars width. Bars are by default width 0.8, so we'll add 0.1 to the left coordinates
# so that each bar is centered
# x-axis values
xs = [i + 0.1 for i, _ in enumerate(movies)]
# print(xs)   # now indexes are not integers!!! -> [0.1, 1.1, 2.1, 3.1, 4.1]

# plot bars with left x-coordinates [xs], heights [num_oscars]
plt.bar(xs, num_oscars)

# title and x and y labels
plt.title("My Favorite Movies")     # graph title
plt.xlabel("Movie")
plt.ylabel("# of Academy Awards")   # label y-axis

# label x-axis with movie names at bar centers
plt.xticks([i + 0.5 for i, _ in enumerate(movies)], movies)

# show the graph
plt.show()

# %% [markdown]
# ## Line Charts

# %%
import matplotlib.pyplot as plt

# y-axis values, data to graph
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]

# x-axis values
xs = [i for i, _ in enumerate(variance)]

# we can make multiple calls to plt.plot
# to show multiple series on the same chart
plt.plot(xs, variance, 'g-', label='variance')          # green solid line
plt.plot(xs, bias_squared, 'r-.', label='bias^2')       # red dot-dashed line
plt.plot(xs, total_error, 'b:', label='total error')    # blue dotted line

# because we've assigned labels to each series
# we can get a legend for free
# loc=9 means "top center"
plt.legend(loc=9)
plt.xlabel("model complexity")
plt.title("The Bias-Variance Tradeoff")

# show the graph
plt.show()

# %% [markdown]
# ## Scatterplots

# %%
# x-axis values, and y-axis values, and labels for each data point
friends = [ 70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels =  ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

# create scatter plot
plt.scatter(friends, minutes)

# label each point
for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label,
        xy=(friend_count, minute_count),    # put the label with its point
        xytext=(5, -5),                     # but slightly offset
        textcoords='offset points')

# title and x and y labels
plt.title("Daily Minutes vs. Number of Friends")
plt.xlabel("# of friends")
plt.ylabel("daily minutes spent on the site")

# show the graph
plt.show()

# %%
# If you’re scattering comparable variables, you might get a misleading picture if you let matplotlib choose the scale, as in the following figure

# data values for x and y axis
test_1_grades = [ 99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]

# create scatter plot
plt.scatter(test_1_grades, test_2_grades)

# title and x and y labels
plt.title("Axes Aren't Comparable")
plt.xlabel("test 1 grade")
plt.ylabel("test 2 grade")

# show the graph
plt.show()

# %%
# If we include a call to plt.axis("equal"), the plot above more accurately shows that most of the variation occurs on test 2.

# data values for x and y axis
test_1_grades = [ 99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]

plt.axis("equal")

# create scatter plot
plt.scatter(test_1_grades, test_2_grades)

# title and x and y lables
plt.title("Axes Aren't Comparable")
plt.xlabel("test 1 grade")
plt.ylabel("test 2 grade")

# show the graph
plt.show()
